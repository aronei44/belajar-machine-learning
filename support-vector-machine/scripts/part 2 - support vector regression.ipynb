# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, StandardScaler, PolynomialFeatures

# %%
df = pd.read_csv("../../datasets/CarPrice.csv", index_col="car_ID")
df.drop(labels=['CarName'], axis=1, inplace=True)
df.head()
# Out:
#         symboling fueltype aspiration doornumber      carbody drivewheel  \
# car_ID
# 1               3      gas        std        two  convertible        rwd
# 2               3      gas        std        two  convertible        rwd
# 3               1      gas        std        two    hatchback        rwd
# 4               2      gas        std       four        sedan        fwd
# 5               2      gas        std       four        sedan        4wd
#
#        enginelocation  wheelbase  carlength  carwidth  ...  enginesize  \
# car_ID                                                 ...
# 1               front       88.6      168.8      64.1  ...         130
# 2               front       88.6      168.8      64.1  ...         130
# 3               front       94.5      171.2      65.5  ...         152
# 4               front       99.8      176.6      66.2  ...         109
# 5               front       99.4      176.6      66.4  ...         136
#
#         fuelsystem boreratio stroke  compressionratio horsepower  peakrpm  \
# car_ID
# 1             mpfi      3.47   2.68               9.0        111     5000
# 2             mpfi      3.47   2.68               9.0        111     5000
# 3             mpfi      2.68   3.47               9.0        154     5000
# 4             mpfi      3.19   3.40              10.0        102     5500
# 5             mpfi      3.19   3.40               8.0        115     5500
#
#         citympg  highwaympg    price
# car_ID
# 1            21          27  13495.0
# 2            21          27  16500.0
# 3            19          26  16500.0
# 4            24          30  13950.0
# 5            18          22  17450.0
#
# [5 rows x 24 columns]

# %% [markdown]
# ## splitting

# %%
X = df.drop(labels=['price'], axis=1)
y = df.price

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((164, 23), (41, 23), (164,), (41,))

# %% [markdown]
# ## training

# %%
numerical_pipeline = Pipeline([
    ("inputer", SimpleImputer(strategy="mean")),
    ("scaler", StandardScaler())
])
categorical_pipeline = Pipeline([
    ("inputer", SimpleImputer(strategy="most_frequent")),
    ("onehot", OneHotEncoder(handle_unknown = 'ignore'))
])

# %%
X_train.head()
# Out:
#         symboling fueltype aspiration doornumber    carbody drivewheel  \
# car_ID
# 67              0   diesel        std       four      sedan        rwd
# 112             0      gas        std       four      sedan        rwd
# 154             0      gas        std       four      wagon        fwd
# 97              1      gas        std       four      sedan        fwd
# 39              0      gas        std        two  hatchback        fwd
#
#        enginelocation  wheelbase  carlength  carwidth  ...  cylindernumber  \
# car_ID                                                 ...
# 67              front      104.9      175.0      66.1  ...            four
# 112             front      107.9      186.7      68.4  ...            four
# 154             front       95.7      169.7      63.6  ...            four
# 97              front       94.5      165.3      63.8  ...            four
# 39              front       96.5      167.5      65.2  ...            four
#
#         enginesize fuelsystem boreratio  stroke compressionratio  horsepower  \
# car_ID
# 67             134        idi      3.43    3.64             22.0          72
# 112            120       mpfi      3.46    2.19              8.4          95
# 154             92       2bbl      3.05    3.03              9.0          62
# 97              97       2bbl      3.15    3.29              9.4          69
# 39             110       1bbl      3.15    3.58              9.0          86
#
#         peakrpm  citympg  highwaympg
# car_ID
# 67         4200       31          39
# 112        5000       19          24
# 154        4800       31          37
# 97         5200       31          37
# 39         5800       27          33
#
# [5 rows x 23 columns]

# %%
preprocessor = ColumnTransformer([
    ("numeric", numerical_pipeline, ['wheelbase','enginesize','boreratio','stroke','compressionratio','horsepower','peakrpm','citympg','highwaympg']),
    ("categoric", categorical_pipeline, ['symboling','fueltype','aspiration','doornumber','carbody','drivewheel','enginelocation','enginetype','cylindernumber','fuelsystem'])
])

# %%
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
pipeline = Pipeline([
    ("prep", preprocessor),
    ("algo", SVR())
])

# %%
# pipeline.get_params()

# %%
from sklearn.model_selection import GridSearchCV

parameter = {
    'algo__C' : [1,1.5,2,2.5,3,3.5,4,4.5,5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10],
    'algo__gamma' : ('auto','scale'),
},

model = GridSearchCV(pipeline, parameter, cv=3, n_jobs=-1, verbose=1)
model.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 38 candidates, totalling 114 fits
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('prep',
#                                         ColumnTransformer(transformers=[('numeric',
#                                                                          Pipeline(steps=[('inputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['wheelbase',
#                                                                           'enginesize',
#                                                                           'boreratio',
#                                                                           'stroke',
#                                                                           'compressionratio',
#                                                                           'horsepower',
#                                                                           'peakrpm',
#                                                                           'citympg',
#                                                                           'highwaympg']),
#                                                                         ('categoric',
#                                                                          Pipeline(steps=[('inputer',
#                                                                                           SimpleImputer(strategy='mos...ent')),
#                                                                                          ('onehot',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['symboling',
#                                                                           'fueltype',
#                                                                           'aspiration',
#                                                                           'doornumber',
#                                                                           'carbody',
#                                                                           'drivewheel',
#                                                                           'enginelocation',
#                                                                           'enginetype',
#                                                                           'cylindernumber',
#                                                                           'fuelsystem'])])),
#                                        ('algo', SVR())]),
#              n_jobs=-1,
#              param_grid=({'algo__C': [1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6,
#                                       6.5, 7, 7.5, 8, 8.5, 9, 9.5, 10],
#                           'algo__gamma': ('auto', 'scale')},),
#              verbose=1)

# %%
model.best_params_
# Out:
# {'algo__C': 10, 'algo__gamma': 'scale'}

# %%
model.score(X_train, y_train), model.best_score_, model.score(X_test, y_test)
# Out:
# (-0.07937571040183222, -0.10794518260572539, -0.0760196784433449)

# %% [markdown]
# ## ga cocok. ga bagus

# %% [markdown]
# ### polynomial features (pangkat linear)

# %%
numerical_pipeline = Pipeline([
    ("inputer", SimpleImputer(strategy="mean")),
    ("scaler", StandardScaler()),
    ("poly",PolynomialFeatures())
])
categorical_pipeline = Pipeline([
    ("inputer", SimpleImputer(strategy="most_frequent")),
    ("onehot", OneHotEncoder(handle_unknown = 'ignore'))
])

preprocessor = ColumnTransformer([
    ("numeric", numerical_pipeline, ['wheelbase','enginesize','boreratio','stroke','compressionratio','horsepower','peakrpm','citympg','highwaympg']),
    ("categoric", categorical_pipeline, ['symboling','fueltype','aspiration','doornumber','carbody','drivewheel','enginelocation','enginetype','cylindernumber','fuelsystem'])
])
pipeline = Pipeline([
    ("prep", preprocessor),
    ("algo", SVR())
])
parameter = {
    'algo__C' : [1,1.5,2,2.5,3,3.5,4,4.5,5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10],
    'algo__gamma' : ('auto','scale'),
    'prep__numeric__poly__degree' : [1,2],
    'prep__numeric__poly__interaction_only' : [True, False],
},

model = GridSearchCV(pipeline, parameter, cv=3, n_jobs=-1, verbose=1)
model.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 152 candidates, totalling 456 fits
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('prep',
#                                         ColumnTransformer(transformers=[('numeric',
#                                                                          Pipeline(steps=[('inputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           StandardScaler()),
#                                                                                          ('poly',
#                                                                                           PolynomialFeatures())]),
#                                                                          ['wheelbase',
#                                                                           'enginesize',
#                                                                           'boreratio',
#                                                                           'stroke',
#                                                                           'compressionratio',
#                                                                           'horsepower',
#                                                                           'peakrpm',
#                                                                           'citympg',
#                                                                           'highwaympg']),
#                                                                         ('categoric',
#                                                                          Pipeline(steps=[('inpute...
#                                                                           'aspiration',
#                                                                           'doornumber',
#                                                                           'carbody',
#                                                                           'drivewheel',
#                                                                           'enginelocation',
#                                                                           'enginetype',
#                                                                           'cylindernumber',
#                                                                           'fuelsystem'])])),
#                                        ('algo', SVR())]),
#              n_jobs=-1,
#              param_grid=({'algo__C': [1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6,
#                                       6.5, 7, 7.5, 8, 8.5, 9, 9.5, 10],
#                           'algo__gamma': ('auto', 'scale'),
#                           'prep__numeric__poly__degree': [1, 2],
#                           'prep__numeric__poly__interaction_only': [True,
#                                                                     False]},),
#              verbose=1)

# %%
model.score(X_train, y_train), model.best_score_, model.score(X_test, y_test)
# Out:
# (-0.07905280864589126, -0.10772174851321854, -0.07565646254752334)

# %% [markdown]
# # save model

# %%
import pickle

# %%
pickle.dump(model, open("../models/svm_carprice.pkl",'wb'))

# %%
model = pickle.load(open("../models/svm_carprice.pkl", "rb"))
model
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('prep',
#                                         ColumnTransformer(transformers=[('numeric',
#                                                                          Pipeline(steps=[('inputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           StandardScaler()),
#                                                                                          ('poly',
#                                                                                           PolynomialFeatures())]),
#                                                                          ['wheelbase',
#                                                                           'enginesize',
#                                                                           'boreratio',
#                                                                           'stroke',
#                                                                           'compressionratio',
#                                                                           'horsepower',
#                                                                           'peakrpm',
#                                                                           'citympg',
#                                                                           'highwaympg']),
#                                                                         ('categoric',
#                                                                          Pipeline(steps=[('inpute...
#                                                                           'aspiration',
#                                                                           'doornumber',
#                                                                           'carbody',
#                                                                           'drivewheel',
#                                                                           'enginelocation',
#                                                                           'enginetype',
#                                                                           'cylindernumber',
#                                                                           'fuelsystem'])])),
#                                        ('algo', SVR())]),
#              n_jobs=-1,
#              param_grid=({'algo__C': [1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6,
#                                       6.5, 7, 7.5, 8, 8.5, 9, 9.5, 10],
#                           'algo__gamma': ('auto', 'scale'),
#                           'prep__numeric__poly__degree': [1, 2],
#                           'prep__numeric__poly__interaction_only': [True,
#                                                                     False]},),
#              verbose=1)
